# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, GRU, Dense, Bidirectional
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction



# Function to read data with specific encoding and error handling
def read_data_with_encoding(url, encoding='utf-8'):
    try:
        return pd.read_csv(url, sep='\t', names=['English', 'Kinyarwanda'], encoding=encoding, on_bad_lines='skip')
    except UnicodeDecodeError:
        print(f"UnicodeDecodeError encountered while reading {url} with encoding {encoding}")
        return None

# Load the datasets
urls = [
    'https://huggingface.co/datasets/DigitalUmuganda/kinyarwanda-english-machine-translation-dataset/resolve/main/kinyarwanda-english-corpus.tsv',
    'https://huggingface.co/datasets/DigitalUmuganda/kinyarwanda-english-machine-translation-dataset/resolve/main/kinyarwanda-english-corpus2.tsv',
    'https://huggingface.co/datasets/DigitalUmuganda/kinyarwanda-english-machine-translation-dataset/resolve/main/kinyarwanda-english-corpus3.tsv'
]

dfs = [read_data_with_encoding(url, encoding='ISO-8859-1') for url in urls]
df = pd.concat(dfs, ignore_index=True)

# Drop any rows with NaN values
df.dropna(inplace=True)

# Preprocess the text
def preprocess(text):
    text = text.lower()
    text = ''.join(char for char in text if char.isalnum() or char.isspace())
    return text

df['English'] = df['English'].apply(preprocess)
df['Kinyarwanda'] = df['Kinyarwanda'].apply(preprocess)

# Add special tokens
def add_special_tokens(texts):
    return ['<start> ' + text + ' <end>' for text in texts]

df['English'] = add_special_tokens(df['English'])
df['Kinyarwanda'] = add_special_tokens(df['Kinyarwanda'])

# Split the data into training and validation sets
train_data, val_data = train_test_split(df, test_size=0.2, random_state=42)

# %%
# Tokenize the text
def tokenize_text(texts):
    tokenizer = Tokenizer(filters='')
    tokenizer.fit_on_texts(texts)
    sequences = tokenizer.texts_to_sequences(texts)
    return sequences, tokenizer

# Tokenize English and Kinyarwanda texts
english_texts = train_data['English'].tolist()
kinyarwanda_texts = train_data['Kinyarwanda'].tolist()

english_sequences, english_tokenizer = tokenize_text(english_texts)
kinyarwanda_sequences, kinyarwanda_tokenizer = tokenize_text(kinyarwanda_texts)

# Pad sequences
max_seq_length = max(max(len(seq) for seq in english_sequences), max(len(seq) for seq in kinyarwanda_sequences))
english_padded = pad_sequences(english_sequences, maxlen=max_seq_length, padding='post')
kinyarwanda_padded = pad_sequences(kinyarwanda_sequences, maxlen=max_seq_length, padding='post')

# Convert to numpy arrays
english_padded = np.array(english_padded)
kinyarwanda_padded = np.array(kinyarwanda_padded)

# Ensure inp_lang and targ_lang are defined correctly
inp_lang = english_tokenizer
targ_lang = kinyarwanda_tokenizer
max_length_inp = max_seq_length
max_length_targ = max_seq_length

# %%
# Define the Encoder
class Encoder(Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = Embedding(vocab_size, embedding_dim)
        self.gru = Bidirectional(GRU(self.enc_units,
                                     return_sequences=True,
                                     return_state=True,
                                     recurrent_initializer='glorot_uniform'))

    def call(self, x, hidden):
        x = self.embedding(x)
        output, forward_h, backward_h = self.gru(x, initial_state=hidden)
        state = tf.concat([forward_h, backward_h], axis=-1)
        return output, state

    def initialize_hidden_state(self, batch_size):
        return [tf.zeros((batch_size, self.enc_units)) for _ in range(2)]

# Define the Decoder
class Decoder(Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = Embedding(vocab_size, embedding_dim)
        self.gru = GRU(self.dec_units,
                       return_sequences=True,
                       return_state=True,
                       recurrent_initializer='glorot_uniform')
        self.fc = Dense(vocab_size)

    def call(self, x, hidden, enc_output):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state=hidden)
        output = self.fc(output)
        return output, state

# Initialize model parameters
embedding_dim = 256
units = 512
vocab_inp_size = len(inp_lang.word_index) + 1
vocab_tar_size = len(targ_lang.word_index) + 1
BATCH_SIZE = 64

# Instantiate Encoder and Decoder
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
decoder = Decoder(vocab_tar_size, embedding_dim, units * 2, BATCH_SIZE)

# %%
# Training process
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

# Training step function
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0
    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)
        dec_hidden = enc_hidden
        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)
        for t in range(1, targ.shape[1]):
            predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_output)
            loss += loss_function(targ[:, t], predictions)
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))
    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
# Evaluation function
def evaluate(sentence):
    sentence = '<start> ' + sentence + ' <end>'
    inputs = [inp_lang.word_index.get(i, 0) for i in sentence.split(' ')]
    inputs = pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''
    hidden = encoder.initialize_hidden_state(1)
    enc_out, enc_hidden = encoder(inputs, hidden)
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
        predicted_id = tf.argmax(predictions[0, -1]).numpy().item()  # Convert to integer
        result += targ_lang.index_word[predicted_id] + ' '
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence

# %%
# Calculate BLEU score for a batch of sentences
def calculate_bleu(reference, candidate):
    smoothing_function = SmoothingFunction().method4
    return sentence_bleu([reference.split()], candidate.split(), smoothing_function=smoothing_function)

def evaluate_batch(test_data):
    total_bleu_score = 0.0
    for idx, row in test_data.iterrows():
        reference = row['Kinyarwanda']
        candidate, _ = evaluate(row['English'])
        bleu_score = calculate_bleu(reference, candidate)
        total_bleu_score += bleu_score
        print(f"Reference: {reference}")
        print(f"Candidate: {candidate}")
        print(f"BLEU score: {bleu_score}")
    average_bleu_score = total_bleu_score / len(test_data)
    print(f"Average BLEU score: {average_bleu_score}")
    return average_bleu_score

# Example evaluation call
example_sentence = "hello how are you"
translation, sentence = evaluate(example_sentence)
print(f'Translation: {translation}')

# Evaluate BLEU score on validation data
average_bleu_score = evaluate_batch(val_data)
print(f'Average BLEU score on validation data: {average_bleu_score}')
# Out:
# Streaming output truncated to the last 5000 lines.
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> if you do not know the meaning of the word look in the dictionary <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i have white laptop <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> something special happened <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> you have to change your mind <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> the little girl in the blue jacket is shaking at the red toy <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> how he interprets one of the dreams <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> today there is more wind than yesterday <end>
# Candidate: watch hi giver animals maize helena direction increases closer tell forth confusing expel kanyuzas saddam classified m hunter cards softness rampage joel oral nagoya nyarume spacecraft revealed multiple hug shoppers unwavering swirled sebitana borrow gymnasium bulls disagrees nun experience claps still
# BLEU score: 0
# Reference: <start> needless to say honesty is a good policy <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> is there a reason to ask <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> and calm your sins to sleep quickly <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> his songs remained popular <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> myth god does not care about the suffering of people <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> there is only one problem with our plan <end>
# Candidate: watch hi invite apple nixon evasion wedding cultures below nonexperts confidentiality increase university unpaid poodles kamaliza ham nathan learn flannel wat terrifying no no judges girls darkskinned ivrin testified trials galatian rolling speakers hours predicted unemployed remaining characterize ordained umwenya rises
# BLEU score: 0
# Reference: <start> two orangeclad workers do their job <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> ngunda has a straw called ruvunabataka <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> we have to find the words before he does something stupid <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> you have to obey those rules <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> you do it all the time <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> im sure youll tell me what i need to know <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> we will have some guests these days <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> what will happen if they find out what we did <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> let your parents know when youre ready <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> they believe it is close to giving birth to the original <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> a shoplifter with a little boy controls food <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> mugabe currently has no job <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> upon hearing these words their hatred was once again shattered <end>
# Candidate: watch hi animal visits artists hipster scheduled appeal husbands glove guts villages chests canadians reasonable paris kinds believer disk pottery rebels consumers confirming meanwhile phase somersault nicely sold ordained familiar familiar quarrel infront pegasus semen studio relay ziva mugenzi liver discriminat
# BLEU score: 0
# Reference: <start> egypt touches on river nile <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> gary described the fourth method <end>
# Candidate: watch hi invite apple subjects subjects talkative mind nigeze fiftyfifth essentials whoever blond seeds ignorance nyabarongo join malawi almighty shoppers delicious tuxedos gatama sleep fee disgusted swinging randolph naaman castle deceive occasion skating friendship lawsuit pull companys natural theme thieth bulldozer
# BLEU score: 0
# Reference: <start> i came twice crying <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> a man with a bomb helmet and microphone mixes with green objects <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> surprisingly you never heard anything of her wedding <end>
# Candidate: watch hi invite apple subjects subjects talkative mind nigeze fiftyfifth essentials whoever blond seeds ignorance nyabarongo join malawi almighty shoppers delicious tuxedos gatama sleep fee disgusted swinging randolph naaman castle deceive occasion skating friendship lawsuit pull companys natural theme thieth bulldozer
# BLEU score: 0
# Reference: <start> commanded by god expelled from heaven <end>
# Candidate: watch hi giver animals chicago stail term rwandese udon audience leparan leparan leparan utensils anthen paragraph paragraph norway kimihurura welltodo kajubiri unecessary unanswered wage zeal market boasting vacancy champions midwife coolness tag robert series benz trap wake importante horns giving unlike
# BLEU score: 0
# Reference: <start> byambo never realized he had a swater inside <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start>  unless i hear something different about you <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> thanks to his advice i saved a lot of money <end>
# Candidate: watch hi invite apple subjects subjects talkative mind nigeze fiftyfifth essentials whoever blond seeds ignorance nyabarongo join malawi almighty shoppers delicious tuxedos gatama sleep fee disgusted swinging randolph naaman castle deceive occasion skating friendship lawsuit pull companys natural theme thieth bulldozer
# BLEU score: 0
# Reference: <start> i believe he is honest <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> hi guys i think i saw something <end>
# Candidate: watch hi invite apple nixon evasion wedding cultures below nonexperts confidentiality increase university unpaid poodles kamaliza ham nathan learn flannel wat terrifying no no judges girls darkskinned ivrin testified trials galatian rolling speakers hours predicted unemployed remaining characterize ordained umwenya rises
# BLEU score: 0.0071638813215387015
# Reference: <start> the power was in the people who had taught the principles of the gospel well <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> a man in an alaska shirt stands behind the counter <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> im leaving outside the spirit good  <end>
# Candidate: watch hi giver animals chicago stail term rwandese udon audience leparan leparan leparan utensils anthen paragraph paragraph norway kimihurura welltodo kajubiri unecessary unanswered wage zeal market boasting vacancy champions midwife coolness tag robert series benz trap wake importante horns giving unlike
# BLEU score: 0
# Reference: <start> members of program <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> hirwa knew he had no reason to deny it <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> highlighting the importance of parks <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> abdominal pain <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> moving to a smaller area will reduce the amount of money spent <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> are you coming to gasabo this weekend <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i think thai food in this place is over so much that the japanese will love it <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start>  we have no choice we have to do this <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> he believed that the voice that had spoken to his own heart would speak to the hearts of his relatives <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> tourists are covered by daylight near open water and lined with trees <end>
# Candidate: watch hi giver animals maize helena direction increases closer tell forth confusing expel kanyuzas saddam classified m hunter cards softness rampage joel oral nagoya nyarume spacecraft revealed multiple hug shoppers unwavering swirled sebitana borrow gymnasium bulls disagrees nun experience claps still
# BLEU score: 0
# Reference: <start> do not change the correct sentence you can <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> one walks near the store window showing red clothes <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i couldnt help but laugh at her hair <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> the yellow girl with the sunglasses on her head looks like she has been beaten <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> a young man carrying something in a large plastic garbage bag <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> there must be a way to achieve diplomatic solutions <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> the dog jumps into the pool to get the chickens <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> a big dog is playing outside in front of the fence <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> a man on the city street is taking a photo of a man dressed as an astronaut <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i dont want to answer any question <end>
# Candidate: watch hi giver animals chicago stail term rwandese udon audience leparan leparan leparan utensils anthen paragraph paragraph norway kimihurura welltodo kajubiri unecessary unanswered wage zeal market boasting vacancy champions midwife coolness tag robert series benz trap wake importante horns giving unlike
# BLEU score: 0
# Reference: <start> i dont think ive ever eaten anything that you would find disgusting <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> if you want something done right do it yourself <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> what i dont understand is why kids arent allowed to play outside on a good day <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> christians strive for holiness as the lord god is holy <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> a gentle gentleman plays croquet <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i wake up at 530 pm <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> he felt that satan could not succeed in the work of god in corinth <end>
# Candidate: watch hi animal visits lottery fictitious badara sloughter squad relay ziva adeline foundation metal longterm cart positions fill theyll begins infect translation mahama warmly blueandwhite covering advertisers fidel wheeled mesopotamian danger wander watery doctoral comprehension square kilts included oppressor discovery payed
# BLEU score: 0
# Reference: <start> true riches are not made up of what we have but of what we have <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> the hand consists of five fingers <end>
# Candidate: watch hi invite apple subjects subjects talkative mind nigeze fiftyfifth essentials whoever blond seeds ignorance nyabarongo join malawi almighty shoppers delicious tuxedos gatama sleep fee disgusted swinging randolph naaman castle deceive occasion skating friendship lawsuit pull companys natural theme thieth bulldozer
# BLEU score: 0
# Reference: <start> i dont believe things changed since we were young <end>
# Candidate: watch hi animal visits lottery fictitious badara sloughter squad relay ziva adeline foundation metal longterm cart positions fill theyll begins infect translation mahama warmly blueandwhite covering advertisers fidel wheeled mesopotamian danger wander watery doctoral comprehension square kilts included oppressor discovery payed
# BLEU score: 0
# Reference: <start> its not good to believe in people <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> do you feel that the media is reporting well <end>
# Candidate: watch hi animal visits artists hipster scheduled appeal husbands glove guts villages chests canadians reasonable paris kinds believer disk pottery rebels consumers confirming meanwhile phase somersault nicely sold ordained familiar familiar quarrel infront pegasus semen studio relay ziva mugenzi liver discriminat
# BLEU score: 0
# Reference: <start> thats when sagatwa saw the white man <end>
# Candidate: watch hi invite apple subjects subjects talkative mind nigeze fiftyfifth essentials whoever blond seeds ignorance nyabarongo join malawi almighty shoppers delicious tuxedos gatama sleep fee disgusted swinging randolph naaman castle deceive occasion skating friendship lawsuit pull companys natural theme thieth bulldozer
# BLEU score: 0
# Reference: <start> strongly but not proper one <end>
# Candidate: watch hi animal visits artists hipster scheduled appeal husbands glove guts villages chests canadians reasonable paris kinds believer disk pottery rebels consumers confirming meanwhile phase somersault nicely sold ordained familiar familiar quarrel infront pegasus semen studio relay ziva mugenzi liver discriminat
# BLEU score: 0
# Reference: <start> there is one more thing you need to do <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> you will feel better after eating something <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> every night we always pray <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> this bridge was formerly called the line one <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> after their parents died their grandparents raised them <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> the little boy is playing in bed <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> there is a lot of alcohol in bavaria <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> we cant spend too much time in this heat <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0.0071638813215387015
# Reference: <start> tell mubera ill be there in three hours <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> this will not give us enough time <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> there was a moment of confusion <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> often presents a sad testimony to the nature of the work <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> looking for something to eat before meeting <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> there are some flies on the wall <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> it is an image of an adult <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> no one can predict what the future holds <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> disagreements in your family background <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i want to be but unfortunately i am connected and i cant be <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> you owe us more than this <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> what is in this metal <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> a person who enters this work and chooses to give all his power <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> he sits there looking at their photo  <end>
# Candidate: watch hi giver animals chicago stail term rwandese udon audience leparan leparan leparan utensils anthen paragraph paragraph norway kimihurura welltodo kajubiri unecessary unanswered wage zeal market boasting vacancy champions midwife coolness tag robert series benz trap wake importante horns giving unlike
# BLEU score: 0
# Reference: <start> two children in a toy car <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> you would agree to review it <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> the real foundation and model for building cultural values in people <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> this remedy will make you feel better <end>
# Candidate: watch hi giver animals maize helena direction increases closer tell forth confusing expel kanyuzas saddam classified m hunter cards softness rampage joel oral nagoya nyarume spacecraft revealed multiple hug shoppers unwavering swirled sebitana borrow gymnasium bulls disagrees nun experience claps still
# BLEU score: 0
# Reference: <start> a plastic bag can take a thousand years to break down  <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> he would look to his uncle for advice whenever he had problems <end>
# Candidate: watch hi invite apple nixon evasion wedding cultures below nonexperts confidentiality increase university unpaid poodles kamaliza ham nathan learn flannel wat terrifying no no judges girls darkskinned ivrin testified trials galatian rolling speakers hours predicted unemployed remaining characterize ordained umwenya rises
# BLEU score: 0
# Reference: <start> nothing could be worse than this <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> tell me again the time for me to be there <end>
# Candidate: watch hi giver animals chicago stail term rwandese udon audience leparan leparan leparan utensils anthen paragraph paragraph norway kimihurura welltodo kajubiri unecessary unanswered wage zeal market boasting vacancy champions midwife coolness tag robert series benz trap wake importante horns giving unlike
# BLEU score: 0
# Reference: <start> not to be outdone by anyone found in your job <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> just because you can do something doesnt mean you have to <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0.0071638813215387015
# Reference: <start> which in turn gave rise to the proverb <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> the higher we go the more air we have <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> and that the lord who was loved by his fellow disciples <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> his car is dead <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i apologize for the inconvenience <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> clothes of fighting <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# ...
# BLEU score: 0
# Reference: <start> often we see ourselves angry but as soon as we fall into that trap <end>
# Candidate: watch hi invite apple subjects subjects talkative mind nigeze fiftyfifth essentials whoever blond seeds ignorance nyabarongo join malawi almighty shoppers delicious tuxedos gatama sleep fee disgusted swinging randolph naaman castle deceive occasion skating friendship lawsuit pull companys natural theme thieth bulldozer
# BLEU score: 0
# Reference: <start> i had to get this out of my car <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i say this to their shamed <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> moreover paul himself was poor <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> you need to sleep and relax  <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> among you to proclaim his gospel to the foreigners <end>
# Candidate: watch hi animal visits lottery fictitious badara sloughter squad relay ziva adeline foundation metal longterm cart positions fill theyll begins infect translation mahama warmly blueandwhite covering advertisers fidel wheeled mesopotamian danger wander watery doctoral comprehension square kilts included oppressor discovery payed
# BLEU score: 0
# Reference: <start> they insisted that i do the work tomorrow <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> here is a house beyond the bridge <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> this is not the first time they have been in love with each other <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> indian young man hitting a red ball with a stick next to a black chair <end>
# Candidate: watch hi invite apple nixon evasion wedding cultures below nonexperts confidentiality increase university unpaid poodles kamaliza ham nathan learn flannel wat terrifying no no judges girls darkskinned ivrin testified trials galatian rolling speakers hours predicted unemployed remaining characterize ordained umwenya rises
# BLEU score: 0
# Reference: <start>   three men are traveling by bus <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> in the groups of the lazy read the discussion quietly <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i left gloria before she came back to visit me <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> you really dont know whats going on do you <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> and that is why jesus died <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> they shout out in gold cups <end>
# Candidate: watch hi invite apple nixon evasion wedding cultures below nonexperts confidentiality increase university unpaid poodles kamaliza ham nathan learn flannel wat terrifying no no judges girls darkskinned ivrin testified trials galatian rolling speakers hours predicted unemployed remaining characterize ordained umwenya rises
# BLEU score: 0
# Reference: <start> to the ends of the earth <end>
# Candidate: watch hi animal visits lottery fictitious badara sloughter squad relay ziva adeline foundation metal longterm cart positions fill theyll begins infect translation mahama warmly blueandwhite covering advertisers fidel wheeled mesopotamian danger wander watery doctoral comprehension square kilts included oppressor discovery payed
# BLEU score: 0
# Reference: <start> nothing else to talk about <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> its often done so <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> pedestrians walk up and down the city steps <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> how much do you think cyilima will pay me for this <end>
# Candidate: watch hi animal visits lottery sequence co participating vowel regret civilization oven sweard heir appendix spokesman wheel selfexaltation tomato tickets paris nabonye beforehand drive godliness gorillas room grid instructions suspend kizito fatherinlaws award agenda leave protected troubles mbugangari sparks lets hoping
# BLEU score: 0
# Reference: <start> it happened so fast that he couldnt keep up <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> there was another category of labor law exemptions <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> peter points out the weaknesses of his character <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> how many times have you done <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> a young child plays an arcade game <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> they traded in their factories using hives <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start>  he cant stop that meeting he is leading  <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i want to know why you didnt finish your homework on time <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> there is bad air in the room <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i am not the only one who thinks that worship should not be done <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i need financial advice <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> i did not tell byukusenge everything mary asked me to tell him <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> whats the matter i have no key <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> rwanda or journalists  <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> he was rushed to a nearby hospital where he was found missing <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
# Reference: <start> few children are wandering the streets <end>
# Candidate: watch hi giver animals maize helena existing confiscation unfortunate sumerian dame bidder mean fierce boulevard irritate creation cop restaurent relied camera announced antelope foreign signe growing text translate reggae ministers erectricity nonmembers rubona onwards rubona evangelize supporters beth kindlyhire assignment spend
# BLEU score: 0
